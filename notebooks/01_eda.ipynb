# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\healthcare project\data\raw\healthcare\train_data.csv")

# Target distribution
sns.countplot(x='Stay', data=df)
plt.xticks(rotation=45)
plt.show()

# Missing values
(df.isnull().mean()*100).sort_values(ascending=False)

# Correlation heatmap
plt.figure(figsize=(12,8))
sns.heatmap(df.select_dtypes(include='number').corr(), cmap='coolwarm')
plt.show()

# %%
df.shape
# Out:
# (318438, 18)

# %%
df.dtypes
# Out:
# case_id                                int64
# Hospital_code                          int64
# Hospital_type_code                    object
# City_Code_Hospital                     int64
# Hospital_region_code                  object
# Available Extra Rooms in Hospital      int64
# Department                            object
# Ward_Type                             object
# Ward_Facility_Code                    object
# Bed Grade                            float64
# patientid                              int64
# City_Code_Patient                    float64
# Type of Admission                     object
# Severity of Illness                   object
# Visitors with Patient                  int64
# Age                                   object
# Admission_Deposit                    float64
# Stay                                  object
# dtype: object

# %%
(df.isnull().mean() * 100).sort_values(ascending=False)
# Out:
# City_Code_Patient                    1.423197
# Bed Grade                            0.035486
# Hospital_code                        0.000000
# Admission_Deposit                    0.000000
# Age                                  0.000000
# Visitors with Patient                0.000000
# Severity of Illness                  0.000000
# Type of Admission                    0.000000
# patientid                            0.000000
# case_id                              0.000000
# Ward_Facility_Code                   0.000000
# Ward_Type                            0.000000
# Department                           0.000000
# Available Extra Rooms in Hospital    0.000000
# Hospital_region_code                 0.000000
# City_Code_Hospital                   0.000000
# Hospital_type_code                   0.000000
# Stay                                 0.000000
# dtype: float64

# %%
import matplotlib.pyplot as plt

df.select_dtypes(include='number').hist(figsize=(12,10))
plt.tight_layout()
plt.show()

# %%
for col in df.select_dtypes(include='object').columns:
    print("\n", col)
    print(df[col].value_counts().head(10))
# Out:
#  Hospital_type_code
# Hospital_type_code
# a    143425
# b     68946
# c     45928
# e     24770
# d     20389
# f     10703
# g      4277
# Name: count, dtype: int64
#
#  Hospital_region_code
# Hospital_region_code
# X    133336
# Y    122428
# Z     62674
# Name: count, dtype: int64
#
#  Department
# Department
# gynecology            249486
# anesthesia             29649
# radiotherapy           28516
# TB & Chest disease      9586
# surgery                 1201
# Name: count, dtype: int64
#
#  Ward_Type
# Ward_Type
# R    127947
# Q    106165
# S     77794
# P      5046
# T      1477
# U         9
# Name: count, dtype: int64
#
#  Ward_Facility_Code
# Ward_Facility_Code
# F    112753
# E     55351
# D     51809
# C     35463
# B     35156
# A     27906
# Name: count, dtype: int64
#
#  Type of Admission
# Type of Admission
# Trauma       152261
# Emergency    117676
# Urgent        48501
# Name: count, dtype: int64
#
#  Severity of Illness
# Severity of Illness
# ...

# %%
df['Stay'].value_counts()
# Out:
# Stay
# 21-30                 87491
# 11-20                 78139
# 31-40                 55159
# 51-60                 35018
# 0-10                  23604
# 41-50                 11743
# 71-80                 10254
# More than 100 Days     6683
# 81-90                  4838
# 91-100                 2765
# 61-70                  2744
# Name: count, dtype: int64

# %%
for col in df.select_dtypes(include='object').columns:
    print(col)
    print(df[col].value_counts().head(10))
# Out:
# Hospital_type_code
# Hospital_type_code
# a    143425
# b     68946
# c     45928
# e     24770
# d     20389
# f     10703
# g      4277
# Name: count, dtype: int64
# Hospital_region_code
# Hospital_region_code
# X    133336
# Y    122428
# Z     62674
# Name: count, dtype: int64
# Department
# Department
# gynecology            249486
# anesthesia             29649
# radiotherapy           28516
# TB & Chest disease      9586
# surgery                 1201
# Name: count, dtype: int64
# Ward_Type
# Ward_Type
# R    127947
# Q    106165
# S     77794
# P      5046
# T      1477
# U         9
# Name: count, dtype: int64
# Ward_Facility_Code
# Ward_Facility_Code
# F    112753
# E     55351
# D     51809
# C     35463
# B     35156
# A     27906
# Name: count, dtype: int64
# Type of Admission
# Type of Admission
# Trauma       152261
# Emergency    117676
# Urgent        48501
# Name: count, dtype: int64
# Severity of Illness
# Severity of Illness
# Moderate    175843
# ...

# %%
import seaborn as sns
sns.countplot(x='Severity of Illness', hue='Stay', data=df)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.select_dtypes(include='number').corr(), cmap='coolwarm')
plt.show()
